# %% [markdown]
# # Lab 1: Independent Component Analysis
#
# ### Machine Learning 2 (2016/2017)
#
# * The lab exercises should be made in groups of two people.
# * The deadline is Wednesday, April 19, 23:59.
# * Assignment should be sent to p.j.j.p.versteeg@uva.nl. The subject line of your email should be "[ML2_2017] lab#_lastname1\_lastname2".
# * Put your and your teammates' names in the body of the email
# * Attach the .IPYNB (IPython Notebook) file containing your code and answers. Naming of the file follows the same rule as the subject line. For example, if the subject line is "[ML2_2016] lab01\_Bongers\_Blom", the attached file should be "lab01\_Bongers\_Blom.ipynb". Only use underscores ("\_") to connect names, otherwise the files cannot be parsed.
#
# Notes on implementation:
#
# * You should write your code and answers in an IPython Notebook: http://ipython.org/notebook.html. If you have problems, please ask.
# * Use __one cell__ for code and markdown answers only!
#     * Put all code in the cell with the `# YOUR CODE HERE' comment.
#     * For theoretical question, put your solution in the YOUR ANSWER HERE cell.
# * Among the first lines of your notebook should be "%pylab inline". This imports all required modules, and your plots will appear inline.
# * NOTE: test your code and make sure we can run your notebook / scripts!

# %% [markdown]
# ### Literature
# In this assignment, we will implement the Independent Component Analysis algorithm as described in chapter 34 of David MacKay's book "Information Theory, Inference, and Learning Algorithms", which is freely available here:
# http://www.inference.phy.cam.ac.uk/mackay/itila/book.html
#
# Read the ICA chapter carefuly before you continue!
#
# ### Notation
#
# $\mathbf{X}$ is the $M \times T$ data matrix, containing $M$ measurements at $T$ time steps.
#
# $\mathbf{S}$ is the $S \times T$ source matrix, containing $S$ source signal values at $T$ time steps. We will assume $S = M$.
#
# $\mathbf{A}$ is the mixing matrix. We have $\mathbf{X} = \mathbf{A S}$.
#
# $\mathbf{W}$ is the matrix we aim to learn. It is the inverse of $\mathbf{A}$, up to indeterminacies (scaling and permutation of sources).
#
# $\phi$ is an elementwise non-linearity or activation function, typically applied to elements of $\mathbf{W X}$.
#
# ### Code
# In the following assignments, you can make use of the signal generators listed below.

# %%
# %pylab inline
matplotlib.rcParams.update({'font.size': 18, 'font.family': 'Arial'})
from scipy.special import *
from scipy import integrate
import sys
# reload(sys)
# sys.setdefaultencoding("utf-8") # because notebooks are retarded

# Signal generators
def sawtooth(x, period=0.2, amp=1.0, phase=0.):
    return (((x / period - phase - 0.5) % 1) - 0.5) * 2 * amp

def sine_wave(x, period=0.2, amp=1.0, phase=0.):
    return np.sin((x / period - phase) * 2 * np.pi) * amp

def square_wave(x, period=0.2, amp=1.0, phase=0.):
    return ((np.floor(2 * x / period - 2 * phase - 1) % 2 == 0).astype(float) - 0.5) * 2 * amp

def triangle_wave(x, period=0.2, amp=1.0, phase=0.):
    return (sawtooth(x, period, 1., phase) * square_wave(x, period, 1., phase) + 0.5) * 2 * amp

def random_nonsingular_matrix(d=2):
    """
    Generates a random nonsingular (invertible) matrix of shape d*d
    """
    epsilon = 0.1
    A = np.random.rand(d, d)
    while abs(np.linalg.det(A)) < epsilon:
        A = np.random.rand(d, d)
    return A

def plot_signals(X, title=""):
    """
    Plot the signals contained in the rows of X.
    """
    figure(figsize=(8,8))
    for i in range(X.shape[0]):
        ax = plt.subplot(X.shape[0], 1, i + 1)
        plot(X[i, :])
        ax.set_xticks([])
        ax.set_yticks([])
    plt.suptitle(title, fontsize=20)
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The following code generates some toy data to work with.

# %%
# Generate data
num_sources = 5
signal_length = 500
t = linspace(0, 1, signal_length)
S = np.c_[sawtooth(t), sine_wave(t, 0.3), square_wave(t, 0.4), triangle_wave(t, 0.25), np.random.randn(t.size)].T
plot_signals(S, 'Original Signals')

# %% [markdown]
# ### 1.1 Make mixtures (5 points)
# Write a function `make_mixtures(S, A)' that takes a matrix of source signals $\mathbf{S}$ and a mixing matrix $\mathbf{A}$, and generates mixed signals $\mathbf{X}$.

# %%
### 1.1 Make mixtures
def make_mixtures(S, A=None):
    return A.dot(S)

A = random_nonsingular_matrix(d=S.shape[0])
X = make_mixtures(S, A)
plot_signals(X)

# %% [markdown]
# ### 1.2 Histogram (5 points)
# Write a function `plot_histograms(X)` that takes a data-matrix $\mathbf{X}$ and plots one histogram for each signal (row) in $\mathbf{X}$. You can use the numpy `histogram()` function.
#
# Plot histograms of the sources and the measurements.
# Which of these distributions (sources or measurements) tend to look more like Gaussians? Can you think of an explanation for this phenomenon? Why is this important for ICA?

# %%
### 1.2 Histogram
titles = ['Sawtooth', 'Sine', 'Square', 'Triangle', 'Random']

def plot_histograms(X, num_bins=10, titles=[]):
    
    hist = np.zeros((X.shape[0], num_bins))
    bin_edges = np.zeros((X.shape[0], num_bins+1))
    figure(figsize=(5*6, 6), facecolor='w', edgecolor='k')
    
    for i, row in enumerate(X): # For each row
        plt.subplot(1,X.shape[0], i+1)
        hist[i,:], bin_edges[i,:] = np.histogram(X[i,:], normed=True, bins=num_bins) # normalized histogram
        plt.hist(X[i,:], normed=True, bins=num_bins) # also calls np.histogram
        plt.title(titles[i])
        
    plt.tight_layout()
    return hist, bin_edges

# Run
num_bins = 20
hist, bin_edges = plot_histograms(X, num_bins, titles)

hist, bin_edges = plot_histograms(S, num_bins, titles)

# %% [markdown]
# ### Solution
#
# The Sawtooth and Triangle signals have approximately a uniform distribution on their range. The square signal has two peaks corresponding to "on" and "off". In the case of the Sine curve, due to its derivative, the density is more concentrated at the peaks and valleys, with a soft decline towards the center. The random signal is sampled from a Gaussian distribution, so naturally it has the bell curve form. On the other hand, the measurement signals resemble the Gaussian curve more, as by the central limit theorem the sum of several random variables tend to a resemble Gaussian in the limit.
#
# ICA makes the assumption that the sources have a non-Gaussian distribution and are independent from each other. Otherwise, the symmetry of the joint Gaussian distribution of the sources do no favor any particular alignment of the latent variable space, which would make it impossible to recover the original sources.

# %% [markdown]
# ### 1.3 Implicit priors (20 points)
# As explained in MacKay's book, an activation function $\phi$ used in the ICA learning algorithm corresponds to a prior distribution over sources. Specifically, $\phi(a) = \frac{d}{da} \ln p(a)$. For each of the following activation functions, derive the source distribution they correspond to.
# $$\phi_0(a) = -\tanh(a)$$
# $$\phi_1(a) = -a + \tanh(a)$$
# $$\phi_2(a) = -a^3$$
# $$\phi_3(a) = -\frac{6a}{a^2 + 5}$$
#
# The normalizing constant is not required, so an answer of the form $p(a) \propto \verb+[answer]+$ is ok.
#
# Plot the activation functions and the corresponding prior distributions. Compare the shape of the priors to the histogram you plotted in the last question.

# %% [markdown]
# ### Solution
#
# Given the differential equation $\frac{d}{da} \ln p(a) = \phi(a)$, the general solution is given by $p(a) = k \exp \left\{ \int \phi(a) da\right\}$, where $k$ is a constant such that $\int_{\Omega} p(a) da = 1$ with $\Omega$ being the domain of $a$. We computed the integration constants by hand, however we omit this calculations for brevity. If required, please let us know. Below, $c$ and $c_i$ represent integration constants.
#
# #### Case $\phi_0(a) = -\tanh(a)$
# $$ \phi_0(a) = - \frac{\sinh(a)}{\cosh(a)} = - \frac{e^a - e^{-a}}{e^a + e^{-a}} $$
#
# Let $u = e^a + e^{-a}$ such that $du = (e^a - e^{-a}) da$
#
# $$ \int - \frac{e^a - e^{-a}}{e^a + e^{-a}} da = - \int \frac{1}{u} du = - \log \lvert u \lvert + c = - \log \lvert 2 \cosh(a) \lvert + c = \log \left( \frac{c}{\cosh(a)} \right) \hspace{5mm} \rightarrow \hspace{5mm} p_0(a) = \frac{1}{\pi \cosh(a)}$$
#
# #### Case $\phi_1(a) = -a + \tanh(a)$
#
# We use the result from above.
#
# $$\int -a + \tanh(a) da = \frac{-a^2}{2} - \log \left( \frac{c_1}{\cosh(a)} \right) + c_2 \hspace{5mm} \rightarrow \hspace{5mm}  p_1(a) = \frac{1}{\sqrt{ 2\pi e}} \exp \left( \frac{-a^2}{2} \right) \cosh(a) $$
#
# #### Case $\phi_2(a) = -a^3$
#
# $$ \int -a^3 da = \frac{-a^4}{4} \hspace{5mm} \rightarrow \hspace{5mm} p_2(a) = \frac{\sqrt{2}}{\Gamma(\frac{1}{4})} \exp \left( \frac{-a^4}{4} \right) $$
#
# #### Case $\phi_3(a) = -\frac{6a}{a^2 + 5}$
#
# Let $u = u^2 + 5$ such that $du = 2a \, da$.
#
# $$ \int-\frac{6a}{a^2 + 5} da = \int \frac{-3}{u} du = - 3 \log \lvert u \lvert +c = - 3 \log \lvert a^2 + 5 \lvert +c \hspace{5mm} \rightarrow \hspace{5mm} p_3(a) = \frac{200 \sqrt{5}}{3 \pi} (a^2 + 5) ^{-3}$$
#
# #### Comparison
#
# For the random signal, none of the priors are appropriate because the source is originally a Gaussian distribution, whereas all of the priors are either sub- or super-Gaussian (see section on Kurtosis at the bottom of this report). For the sawtooth and triangle signals, due to their uniform-like distributions, the $p_2$ prior with an appropriate gain could be suitable. For the cosine and square signals, none of the priors are appropriate due to the bimodality of the source distributions. In the case of the square signal, an activation function specified as $\phi(x) = \delta_{-1}(x) + \delta_1(x)$ would be appropriate.

# %%
### 1.3 Implicit priors (continued)
activation_fx_names = ['Phi 0', 'Phi 1', 'Phi 2', 'Phi 3']

def activation(x, case):
    return {
        0: - np.tanh(x),
        1: -x + np.tanh(x),
        2: -x**3,
        3: (-6. * x) / (x**2 + 5.),
    }[case]

def prior(x, case):
    return {
        0: (1/np.pi) * 1/np.cosh(x),
        1: (1/np.sqrt(2*np.pi*np.exp(1))) * np.exp(-(x**2)/2) * np.cosh(x),
        2: (np.sqrt(2)/gamma(1./4)) * np.exp(-(x**4)/4),
        3: (200*np.sqrt(5))/(3 * np.pi) * (x**2 + 5)**(-3),
    }[case]

# Sample activation functions
x = np.linspace(-1.5,1.5,100)
activ_data = np.array([activation(x,0), activation(x,1), activation(x,2), activation(x,3)])

# Plot activation data
plt.plot(x, activ_data.T)
plt.legend(['$\phi_0$', '$\phi_1$', '$\phi_2$', '$\phi_3$'])
plt.show()

# Sample prior functions
x = np.linspace(-5,5,100)
prior_data = np.array([prior(x,0), prior(x,1), prior(x,2), prior(x,3)])

# Plot prior data
plt.plot(x, prior_data.T)
plt.legend(['$p_0$', '$p_1$', '$p_2$', '$p_3$'])
plt.show()

# Verify that normalization constants are correct
print('Normalization constant verification:')
for i in range(4):
    prior_fn = lambda x: prior(x,i)
    res = integrate.quad(prior_fn, -100, 100)
    print('   Prior %d: Integral: %f - Error: %s' % (i , res[0], res[1]))
# Out:
# Normalization constant verification:
#    Prior 0: Integral: 1.000000 - Error: 1.76288139962e-11
#    Prior 1: Integral: 1.000000 - Error: 7.80261749894e-14
#    Prior 2: Integral: 1.000000 - Error: 2.25143680377e-11
#    Prior 3: Integral: 1.000000 - Error: 6.80741865747e-11

# %% [markdown]
# ### 1.4 Whitening (15 points)
# Some ICA algorithms can only learn from whitened data. Write a method `whiten(X)` that takes a $M \times T$ data matrix $\mathbf{X}$ (where $M$ is the dimensionality and $T$ the number of examples) and returns a whitened matrix. If you forgot what whitening is or how to compute it, various good sources are available online, such as http://courses.media.mit.edu/2010fall/mas622j/whiten.pdf

# %%
### 1.4 Whitening

def whiten(X):
    cov = np.cov(X)
    Lambda, Phi = np.linalg.eig(cov)

    Y = Phi.T.dot(X)
    L_sqrt = np.sqrt(np.diag(1/Lambda))

    W = L_sqrt.dot(Y)
    return W
    
Xw = whiten(X)

# %% [markdown]
# ### 1.5 Interpret results of whitening (10 points)
# Make scatter plots of the sources, measurements and whitened measurements. Each axis represents a source/measurement and each time-instance is plotted as a dot in this space. You can use the `np.scatter()` function. Describe what you see.
#
# Now compute the covariance matrix of the sources, the measurements and the whitened measurements. You can visualize a covariance matrix using this code:
# ```python
# # Dummy covariance matrix C;
# C = np.eye(5)
# ax = imshow(C, cmap='gray', interpolation='nearest')
# ```
#
# Are the signals independent after whitening?

# %%
### 1.5 Interpret results of whitening 
def plot_scatter(X, title=""):
    plt.figure(figsize=(15,15))
    ctr = 1
    for i in range(X.shape[0]):
        for j in range(X.shape[0]):
            plt.subplot(X.shape[0],X.shape[0], ctr)
            ctr +=1 
            plt.scatter(X[i], X[j])
#     plt.tight_layout()
    plt.suptitle(title, fontsize=18)
    plt.show()
    
plot_scatter(S, 'Source') 
    
plot_scatter(X, 'Data')

plot_scatter(Xw, 'Whitened Data')
  
# Normal data
plt.figure()
plt.subplot(1,3,1)
ax = imshow(np.cov(S), cmap='gray', interpolation='nearest')
plt.title('Sources')
    
# Normal data
plt.subplot(1,3,2)
ax = imshow(np.cov(X), cmap='gray', interpolation='nearest')
plt.title('Data')

# Whitened data
plt.subplot(1,3,3)
ax = imshow(np.cov(Xw), cmap='gray', interpolation='nearest')
plt.title('Whitened data')
plt.show()

# %% [markdown]
# ### Solution
#
# The source signals have a very strong patterns. The measurements are highly correlated. After whitening the measurements, we can no longer observe the correlation. By whitening, we rotate and stretch the data. We can also observe that the covariance matrix is the identity after whitening.

# %% [markdown]
# ### 1.6 Covariance (5 points)
# Explain what a covariant algorithm is.

# %% [markdown]
# ### Solution
#
# Any (consistent) algorithm can be called covariant if it returns the same result independent of the units in which its quantities are measured.

# %% [markdown]
# ### 1.7 Independent Component Analysis (25 points)
# Implement the covariant ICA algorithm as described in MacKay. Write a function `ICA(X, activation_function, learning_rate)`, that returns the demixing matrix $\mathbf{W}$. The input `activation_function` should accept a function such as `lambda a: -tanh(a)`. Update the gradient in batch mode, averaging the gradients over the whole dataset for each update. Try to make it efficient, i.e. use matrix operations instead of loops where possible (loops are slow in interpreted languages such as python and matlab, whereas matrix operations are internally computed using fast C code).

# %%
### 1.7 Independent Component Analysis

def ICA(X, activation_function, learning_rate, S=None, epochs=1000, verbose = False, batch_size=0, num_evaluations=20):

    D,N = X.shape
    W = random_nonsingular_matrix(d=D) # initialize W
    I = np.eye(D)
    
    if batch_size == 0:
        batch_size = N
    
    for epoch in range(epochs):
        
        if batch_size != N:
            rand_samples = numpy.random.choice(N, batch_size) # randomly sample with replacement
            X_batch = X[:,rand_samples]
        else:
            X_batch = X
        
        a = W.dot(X_batch)
        W += learning_rate * (I+ activation_function(a).dot(a.T) / float(batch_size)).dot(W) # update rule
        
    return W

# %% [markdown]
# ### 1.8 Experiments  (5 points)
# Run ICA on the provided signals using each activation function $\phi_0, \ldots, \phi_3$. Plot the retreived signals for each choice of activation function.

# %%
# 1.8 Experiments
plot_signals(S, 'Original Signals')
plt.show()

# Parameters
epochs = 10**5
eta = 1e-3
data = Xw
num_activations = len(activation_fx_names)
W_ls = []

for i in range(num_activations):
    activation_fn = lambda x: activation(x,i)
    W = ICA(data, activation_fn, eta, S, epochs, verbose = True)
    W_ls.append(W)
    
    # Plotting
    plot_signals(W.dot(Xw) , activation_fx_names[i])
    plt.show()

# %% [markdown]
# ### 1.9 Audio demixing (10 points)
# The 'cocktail party effect' refers to the ability humans have to attend to one speaker in a noisy room. We will now use ICA to solve a similar but somewhat idealized version of this problem. The code below loads 5 sound files and plots them.
#
# Use a random non-singular mixing matrix to mix the 5 sound files and save them to disk using the code below so you can listen to them. Plot histograms of the mixed audio and use your ICA implementation to de-mix these and reproduce the original source signals. As in the previous exercise, try each of the activation functions and report your results.
#
# Keep in mind that this problem is easier than the real cocktail party problem, because in real life there are often more sources than measurements (we have only two ears!), and the number of sources is unknown and variable. Also, mixing is not instantaneous in real life, because the sound from one source arrives at each ear at a different point in time. If you have time left, you can think of ways to deal with these issues.

# %%
import scipy.io.wavfile
# Save mixtures to disk, so you can listen to them in your audio player
def save_wav(data, out_file, rate):
    scaled = np.int16(data / np.max(np.abs(data)) * 32767)
    scipy.io.wavfile.write(out_file, rate, scaled)

# %%
# Load audio sources
source_files = ['beet.wav', 'beet9.wav', 'beet92.wav', 'mike.wav', 'street.wav']
wav_data = []
sample_rate = None
for f in source_files:
    sr, data = scipy.io.wavfile.read(f, mmap=False)
    if sample_rate is None:
        sample_rate = sr
    else:
        assert(sample_rate == sr)
    wav_data.append(data[:190000])  # cut off the last part so that all signals have same length

# Create source and measurement data
S_audio = np.c_[wav_data]
plot_signals(S_audio)

A_audio = random_nonsingular_matrix(d=S_audio.shape[0])
X_audio = make_mixtures(S_audio, A_audio)
X_audio_w = whiten(X_audio)

# Histograms of mixed signals
hist, bin_edges = plot_histograms(X_audio, 30, ['Mixed %d' % x for x in range(len(source_files))])

# %%
### 1.9 Audio demixing
plot_signals(X_audio, 'Mixed Signals')
plt.show()

# Parameters
epochs = 3 * 10**3 # should be higher
eta = 1e-2
data = X_audio_w
batch_size = 0

activations = [lambda x: -np.tanh(x),
                lambda x: -x + np.tanh(x),
                lambda x: -x**3,
                lambda x: (-6. *x)/(x**2+5.)]
activation_fx_names = ['Phi 0', 'Phi 1', 'Phi 2', 'Phi 3']

W_audio_ls = []

for i in range(len(activations)):
    activation_fn = activations[i]
    W = ICA(data, activation_fn, eta, S_audio, epochs, verbose = True, batch_size=batch_size)
    W_audio_ls.append(W)
    
    S_pred = W.dot(data)
    # Plotting
    plot_signals(S_pred , activation_fx_names[i])
    
    
# Note: Given that this is a gradient ascent algorithm, a large number of epochs with an appropriate learning rate 
# should provide better results. It is difficult to evaluate the correct values for these parameters as we do 
# not have an evaluation metric.

for i,W in enumerate([W_audio_ls[i] for i in [0,3]]):
    for j, W_row in enumerate(W):
        with open(('./demix/demix_%d_phi_%d.wav'% (j, i)), 'w') as f:
            save_wav(W_row.dot(data), f, sample_rate)

# %%
preds = W_audio_ls[0].dot(X_audio_w)

for i in range(preds.shape[0]):
    with open(('./demix/demix_%d_phi_%d.wav'% (0, i)), 'w') as f:
        save_wav(preds[i,:], f, sample_rate)
sample_rate
# Out:
# 22050

# %% [markdown]
# ### 1.10 Excess Kurtosis (15 points)
# The (excess) kurtosis is a measure of 'peakedness' of a distribution. It is defined as
# $$
# \verb+Kurt+[X] = \frac{\mu_4}{\sigma^4} - 3 = \frac{\operatorname{E}[(X-{\mu})^4]}{(\operatorname{E}[(X-{\mu})^2])^2} - 3
# $$
# Here, $\mu_4$ is known as the fourth moment about the mean, and $\sigma$ is the standard deviation.
# The '-3' term is introduced so that a Gaussian random variable has 0 excess kurtosis.
# We will now try to understand the performance of the various activation functions by considering the kurtosis of the corresponding priors, and comparing those to the empirical kurtosis of our data.
#
# #### 1.10.1 (10 points)
# First, compute analytically the kurtosis of the four priors that you derived from the activation functions before. To do this, you will need the normalizing constant of the distribution, which you can either obtain analytically (good practice!), using computer algebra software (e.g. Sage) or by numerical integration (see scipy.integrate).

# %% [markdown]
# ### Solution
#
# Note that all the priors are symmetric with respect to 0, so $\mu = 0$.
# $$\verb+Kurt+[X] = \frac{\mu_4}{\sigma^4} - 3 = \frac{\operatorname{E}[X^4]}{\operatorname{E}[X^2]^2} - 3$$
#
# #### Case $p_0(a) = \frac{1}{\pi \cosh(a)}$
#
# $$ \verb+Kurt+[X] = \frac{\int_{R} \frac{1}{\pi \cosh(x)} x^4 dx }{\left( \int_{R} \frac{1}{\pi \cosh(x)} x^2 dx \right)^2} - 3 = \frac{\frac{5 \pi^4}{16}} {\frac{\pi^4}{16}} - 3 = 2$$
#
# #### Case $p_1(a) = \frac{1}{\sqrt{ 2\pi e}} \exp \left( \frac{-a^2}{2} \right) \cosh(a)$
#
# $$ \verb+Kurt+[X] = \frac{\int_{R} \frac{1}{\sqrt{ 2\pi e}} \exp \left( \frac{-x^2}{2} \right) \cosh(x) x^4 dx }{\left( \int_{R} \frac{1}{\sqrt{ 2\pi e}} \exp \left( \frac{-x^2}{2} \right) \cosh(x) x^2 dx \right)^2} - 3 = \frac{10}{4} - 3 = -0.5$$
#
# #### Case $p_2(a) = \frac{\sqrt{2}}{\Gamma(\frac{1}{4})} \exp \left( \frac{-a^4}{4} \right)$
#
# $$ \verb+Kurt+[X] = \frac{\int_{R} \frac{\sqrt{2}}{\Gamma(\frac{1}{4})} \exp \left( \frac{-x^4}{4} \right) x^4 dx }{\left( \int_{R} \frac{\sqrt{2}}{\Gamma(\frac{1}{4})} \exp \left( \frac{-x^4}{4} \right) x^2 dx \right)^2} - 3 = \frac{1} {0.45694} - 3 = -0.8115$$
#
# #### Case $p_3(a) = \frac{200 \sqrt{5}}{3 \pi} (a^2 + 5) ^{-3}$
#
# $$ \verb+Kurt+[X] = \frac{\int_{R} \frac{200 \sqrt{5}}{3 \pi} (x^2 + 5) ^{-3} x^4 dx }{\left( \int_{R} \frac{200 \sqrt{5}}{3 \pi} (x^2 + 5) ^{-3} x^2 dx \right)^2} - 3 = \frac{225} {25} - 3 = 6$$
#
#
# Below, you can see the numerical integrations that support this values. Note that these are numerical approximations to improper integrals.

# %%
def mu_k(x, case, k):
    return {
        0: (1/np.pi) * 1/np.cosh(x) * x**k,
        1: (1/np.sqrt(2*np.pi*np.exp(1))) * np.exp(-(x**2)/2) * np.cosh(x)  * x**k,
        2: (np.sqrt(2)/gamma(1.0/4)) * np.exp(-(x**4)/4.0)  * x**k,
        3: (200*np.sqrt(5))/(3 * np.pi) * (x**2 + 5)**(-3) * x**k,
    }[case]

lim = 700

# Verify that normalization constants are correct
print('Theoretical Kurtosis Calculation:')
for i in range(4):
    mu4_fn = lambda x: mu_k(x,i,4)
    mu2_fn = lambda x: mu_k(x,i,2)
    mu4 = integrate.quad(mu4_fn, 0, lim, limit=800)
    mu2 = integrate.quad(mu2_fn, 0, lim, limit=800)
    print('   Prior %d: Kurt: %f' % (i , mu4[0]/(2*mu2[0]**2) - 3))
# Out:
# Theoretical Kurtosis Calculation:
#    Prior 0: Kurt: 2.000000
#    Prior 1: Kurt: -0.500000
#    Prior 2: Kurt: -0.811560
#    Prior 3: Kurt: 5.951195

# %% [markdown]
# #### 1.10.2 (5 points)
# Now use the `scipy.stats.kurtosis` function, with the `fisher` option set to `True`, to compute the empirical kurtosis of the dummy signals and the real audio signals.
#
# Can you use this data to explain the performance of the various activation functions on the synthetic and real data?

# %%
### 1.10.2 Excess Kurtosis
import scipy.stats as st
dum_kurt = st.kurtosis(S, axis=1, fisher=True)
audio_kurt = st.kurtosis(S_audio, axis=1, fisher=True)

print 'Kurtosis for dummy signals:',dum_kurt
print 'Kurtosis for audio signals:', audio_kurt
# Out:
# Kurtosis for dummy signals: [-1.19640244 -1.48287113 -1.84019701 -1.2000384   0.06893589]
# Kurtosis for audio signals: [ 1.79431517  2.06885064  1.93609295  5.05191721  0.53887581]

# %% [markdown]
# For the dummy signals, even though the kurtosis does not match exactly, priors 1 and 2 are closest in terms of kurtosis to the signals, which might explain the good performance in the recovery of the signals seen in Section 1.8.
#
#
# Similarly, priors 0 and 3 are more suited in terms of kurtosis to the real audio signals. This is again consistent with the quality of the recovered sources shown in Section 1.9. Note that in our implementation we use the same prior for all signals. A better performance could be obtained if a different prior was applied per signal.
